# %%
# %load_ext black
# Out:
# The black module is not an IPython extension.

# %%
import sys
import os
import warnings

sys.path.append(os.path.abspath(".."))
warnings.filterwarnings("ignore")

# %%
from src import ImageProcessor, get_data_paths

paths = get_data_paths()
processor = ImageProcessor()

# %%
processor.run(paths["IDRiD"][1])
processor.plot()

# %%
processor.run(paths["IDRiD"][1], noise_type="salt_pepper", percentage=0.2)
processor.plot()

# %%
processor.run(paths["IDRiD"][1], noise_type="gaussian", variance=10)
processor.plot()
