# %%
import cv2
import os

# %%
dir_path = os.path.expanduser("~/Documents/datasets")
os.listdir(dir_path + "/A. Segmentation/1. Original Images/a. Training Set/")
# Out:
# ['IDRiD_16.jpg',
#  'IDRiD_18.jpg',
#  'IDRiD_40.jpg',
#  'IDRiD_50.jpg',
#  'IDRiD_21.jpg',
#  'IDRiD_06.jpg',
#  'IDRiD_36.jpg',
#  'IDRiD_22.jpg',
#  'IDRiD_35.jpg',
#  'IDRiD_24.jpg',
#  'IDRiD_51.jpg',
#  'IDRiD_27.jpg',
#  'IDRiD_54.jpg',
#  'IDRiD_17.jpg',
#  'IDRiD_03.jpg',
#  'IDRiD_10.jpg',
#  'IDRiD_37.jpg',
#  'IDRiD_33.jpg',
#  'IDRiD_05.jpg',
#  'IDRiD_08.jpg',
#  'IDRiD_04.jpg',
#  'IDRiD_25.jpg',
#  'IDRiD_07.jpg',
#  'IDRiD_20.jpg',
#  'IDRiD_32.jpg',
#  'IDRiD_39.jpg',
#  'IDRiD_31.jpg',
#  'IDRiD_15.jpg',
#  'IDRiD_53.jpg',
#  'IDRiD_14.jpg',
#  'IDRiD_44.jpg',
#  'IDRiD_01.jpg',
#  'IDRiD_26.jpg',
#  'IDRiD_11.jpg',
#  'IDRiD_12.jpg',
#  'IDRiD_42.jpg',
#  'IDRiD_29.jpg',
#  'IDRiD_23.jpg',
#  'IDRiD_52.jpg',
#  'IDRiD_19.jpg',
#  'IDRiD_45.jpg',
#  'IDRiD_48.jpg',
#  'IDRiD_41.jpg',
#  'IDRiD_38.jpg',
#  'IDRiD_28.jpg',
#  'IDRiD_34.jpg',
#  'IDRiD_49.jpg',
#  'IDRiD_46.jpg',
#  'IDRiD_43.jpg',
#  'IDRiD_13.jpg',
#  '.ipynb_checkpoints',
#  'IDRiD_47.jpg',
# ...

# %%
img = cv2.imread(os.path.expanduser(dir_path + "/A. Segmentation/1. Original Images/a. Training Set/IDRiD_16.jpg"))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
